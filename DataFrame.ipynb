# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv', index_col='PassengerId')

df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
df.head(3)
# Out:
#              Pclass                              Name     Sex   Age  SibSp  \
# PassengerId
# 892               3                  Kelly, Mr. James    male  34.5      0
# 893               3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 894               2         Myles, Mr. Thomas Francis    male  62.0      0
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 892              0  330911  7.8292   NaN        Q
# 893              0  363272  7.0000   NaN        S
# 894              0  240276  9.6875   NaN        Q

# %%
df.tail()
# Out:
#              Pclass                          Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf    male   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 1308              3           Ware, Mr. Frederick    male   NaN      0      0
# 1309              3      Peter, Master. Michael J    male   NaN      1      1
#
#                          Ticket      Fare Cabin Embarked
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN        S
# 1306                   PC 17758  108.9000  C105        C
# 1307         SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308                     359309    8.0500   NaN        S
# 1309                       2668   22.3583   NaN        C

# %%
df.index
# Out:
# Int64Index([ 892,  893,  894,  895,  896,  897,  898,  899,  900,  901,
#             ...
#             1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309],
#            dtype='int64', name='PassengerId', length=418)

# %%
df.values
# Out:
# array([[3, 'Kelly, Mr. James', 'male', ..., 7.8292, nan, 'Q'],
#        [3, 'Wilkes, Mrs. James (Ellen Needs)', 'female', ..., 7.0, nan,
#         'S'],
#        [2, 'Myles, Mr. Thomas Francis', 'male', ..., 9.6875, nan, 'Q'],
#        ...,
#        [3, 'Saether, Mr. Simon Sivertsen', 'male', ..., 7.25, nan, 'S'],
#        [3, 'Ware, Mr. Frederick', 'male', ..., 8.05, nan, 'S'],
#        [3, 'Peter, Master. Michael J', 'male', ..., 22.3583, nan, 'C']],
#       dtype=object)

# %%
df.shape
# Out:
# (418, 10)

# %%
df.dtypes
# Out:
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     5
# int64      3
# float64    2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.axes
# Out:
# [Int64Index([ 892,  893,  894,  895,  896,  897,  898,  899,  900,  901,
#              ...
#              1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309],
#             dtype='int64', name='PassengerId', length=418),
#  Index(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#         'Cabin', 'Embarked'],
#        dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
new_pd=df[['Age','Fare']]

new_pd
# Out:
#               Age      Fare
# PassengerId
# 892          34.5    7.8292
# 893          47.0    7.0000
# 894          62.0    9.6875
# 895          27.0    8.6625
# 896          22.0   12.2875
# ...           ...       ...
# 1305          NaN    8.0500
# 1306         39.0  108.9000
# 1307         38.5    7.2500
# 1308          NaN    8.0500
# 1309          NaN   22.3583
#
# [418 rows x 2 columns]

# %% [markdown]
# ### Column-Wise and Row-Wise Sum

# %%
new_pd.sum()
# Out:
# Age     10050.5000
# Fare    14856.5376
# dtype: float64

# %%
new_pd.sum(axis=0)
# Out:
# Age     10050.5000
# Fare    14856.5376
# dtype: float64

# %%
new_pd.sum(axis="index")
# Out:
# Age     10050.5000
# Fare    14856.5376
# dtype: float64

# %%
new_pd.sum(axis=1)
# Out:
# PassengerId
# 892      42.3292
# 893      54.0000
# 894      71.6875
# 895      35.6625
# 896      34.2875
#           ...
# 1305      8.0500
# 1306    147.9000
# 1307     45.7500
# 1308      8.0500
# 1309     22.3583
# Length: 418, dtype: float64

# %%
new_pd.sum(axis="columns")
# Out:
# PassengerId
# 892      42.3292
# 893      54.0000
# 894      71.6875
# 895      35.6625
# 896      34.2875
#           ...
# 1305      8.0500
# 1306    147.9000
# 1307     45.7500
# 1308      8.0500
# 1309     22.3583
# Length: 418, dtype: float64

# %% [markdown]
# ### Extract Single Column

# %%
df.Age #Doesn't work if column name has spaces
# Out:
# PassengerId
# 892     34.5
# 893     47.0
# 894     62.0
# 895     27.0
# 896     22.0
#         ...
# 1305     NaN
# 1306    39.0
# 1307    38.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"]
# Out:
# PassengerId
# 892     34.5
# 893     47.0
# 894     62.0
# 895     27.0
# 896     22.0
#         ...
# 1305     NaN
# 1306    39.0
# 1307    38.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df["Age"].head(4)
# Out:
# PassengerId
# 892    34.5
# 893    47.0
# 894    62.0
# 895    27.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Extract Multiple Columns

# %%
df[['Name','Age']]
# Out:
#                                                      Name   Age
# PassengerId
# 892                                      Kelly, Mr. James  34.5
# 893                      Wilkes, Mrs. James (Ellen Needs)  47.0
# 894                             Myles, Mr. Thomas Francis  62.0
# 895                                      Wirz, Mr. Albert  27.0
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ...                                                   ...   ...
# 1305                                   Spector, Mr. Woolf   NaN
# 1306                         Oliva y Ocana, Dona. Fermina  39.0
# 1307                         Saether, Mr. Simon Sivertsen  38.5
# 1308                                  Ware, Mr. Frederick   NaN
# 1309                             Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %%
col=['Name','Age']

df[col]
# Out:
#                                                      Name   Age
# PassengerId
# 892                                      Kelly, Mr. James  34.5
# 893                      Wilkes, Mrs. James (Ellen Needs)  47.0
# 894                             Myles, Mr. Thomas Francis  62.0
# 895                                      Wirz, Mr. Albert  27.0
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ...                                                   ...   ...
# 1305                                   Spector, Mr. Woolf   NaN
# 1306                         Oliva y Ocana, Dona. Fermina  39.0
# 1307                         Saether, Mr. Simon Sivertsen  38.5
# 1308                                  Ware, Mr. Frederick   NaN
# 1309                             Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %% [markdown]
# ### Add New Column in DataFrame

# %%
df["Ship"] = 'Titanic'

df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df.insert(1,'Salutation','Mr.') #OR df.insert(1,column='Salutation',value='Mr.')


df
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# ### Broadcasting Operations

# %%
df["Age"].add(5)
# Out:
# PassengerId
# 892     39.5
# 893     52.0
# 894     67.0
# 895     32.0
# 896     27.0
#         ...
# 1305     NaN
# 1306    44.0
# 1307    43.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"] + 5
# Out:
# PassengerId
# 892     39.5
# 893     52.0
# 894     67.0
# 895     32.0
# 896     27.0
#         ...
# 1305     NaN
# 1306    44.0
# 1307    43.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"].sub(5)
# Out:
# PassengerId
# 892     29.5
# 893     42.0
# 894     57.0
# 895     22.0
# 896     17.0
#         ...
# 1305     NaN
# 1306    34.0
# 1307    33.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"].mul(5)
# Out:
# PassengerId
# 892     172.5
# 893     235.0
# 894     310.0
# 895     135.0
# 896     110.0
#         ...
# 1305      NaN
# 1306    195.0
# 1307    192.5
# 1308      NaN
# 1309      NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"].div(5)
# Out:
# PassengerId
# 892      6.9
# 893      9.4
# 894     12.4
# 895      5.4
# 896      4.4
#         ...
# 1305     NaN
# 1306     7.8
# 1307     7.7
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# ### Value Count Method

# %%
df['Age'].value_counts()
# Out:
# 24.0    17
# 21.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 7.0      1
# 60.5     1
# 26.5     1
# 76.0     1
# 34.5     1
# Name: Age, Length: 79, dtype: int64

# %%
df['Age'].value_counts().sort_index()
# Out:
# 0.17     1
# 0.33     1
# 0.75     1
# 0.83     1
# 0.92     1
#         ..
# 62.00    1
# 63.00    2
# 64.00    3
# 67.00    1
# 76.00    1
# Name: Age, Length: 79, dtype: int64

# %% [markdown]
# ### Drop rows with NULL values

# %%
df.dropna(how = 'all')
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
df.dropna(how = 'any')
# Out:
#              Pclass Salutation  \
# PassengerId
# 904               1        Mr.
# 906               1        Mr.
# 916               1        Mr.
# 918               1        Mr.
# 920               1        Mr.
# ...             ...        ...
# 1296              1        Mr.
# 1297              2        Mr.
# 1299              1        Mr.
# 1303              1        Mr.
# 1306              1        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 904              Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 906          Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 916            Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 918                               Ostby, Miss. Helene Ragnhild  female  22.0
# 920                                    Brady, Mr. John Bertram    male  41.0
# ...                                                        ...     ...   ...
# ...

# %%
df.dropna(how = 'any', axis=1)
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
df.dropna(subset=['Age','Cabin']) #Checks only for mentioned columns
# Out:
#              Pclass Salutation  \
# PassengerId
# 904               1        Mr.
# 906               1        Mr.
# 916               1        Mr.
# 918               1        Mr.
# 920               1        Mr.
# ...             ...        ...
# 1296              1        Mr.
# 1297              2        Mr.
# 1299              1        Mr.
# 1303              1        Mr.
# 1306              1        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 904              Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 906          Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 916            Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 918                               Ostby, Miss. Helene Ragnhild  female  22.0
# 920                                    Brady, Mr. John Bertram    male  41.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Fill NULL values in DataFrame

# %%
df["Age"].fillna(0, inplace=True)

df
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
df["Cabin"].fillna('Cabin Not Avai')

df
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# ### .astype Method to convert datatype of a Column

# %%
#doesn't work on NULL values hence Null should be removed before applying .astype

df['SibSp']
# Out:
# PassengerId
# 892     0
# 893     1
# 894     0
# 895     0
# 896     1
#        ..
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# 1309    1
# Name: SibSp, Length: 418, dtype: int64

# %%
df['SibSp'].astype("float")
# Out:
# PassengerId
# 892     0.0
# 893     1.0
# 894     0.0
# 895     0.0
# 896     1.0
#        ...
# 1305    0.0
# 1306    0.0
# 1307    0.0
# 1308    0.0
# 1309    1.0
# Name: SibSp, Length: 418, dtype: float64

# %%
df['SibSp']=df['SibSp'].astype("float")

df
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex']=df['Sex'].astype("category") #category datatype reduces memory usage

df
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# ### .sort_values() & .sort_index()

# %%
df.sort_values(by='Name', ascending=True)
# Out:
#              Pclass Salutation                                           Name  \
# PassengerId
# 1284              3        Mr.                  Abbott, Master. Eugene Joseph
# 1237              3        Mr.                    Abelseth, Miss. Karen Marie
# 949               3        Mr.                  Abelseth, Mr. Olaus Jorgensen
# 1143              3        Mr.       Abrahamsson, Mr. Abraham August Johannes
# 900               3        Mr.      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ...             ...        ...                                            ...
# 1228              2        Mr.                     de Brito, Mr. Jose Joaquim
# 1152              3        Mr.           de Messemaeker, Mr. Guillaume Joseph
# 907               2        Mr.  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 1236              3        Mr.            van Billiard, Master. James William
# 1084              3        Mr.              van Billiard, Master. Walter John
#
# ...

# %%
df.sort_values(by=['Sex', 'Age'], ascending=True)
# Out:
#              Pclass Salutation  \
# PassengerId
# 914               1        Mr.
# 925               3        Mr.
# 928               3        Mr.
# 957               2        Mr.
# 980               3        Mr.
# ...             ...        ...
# 1085              2        Mr.
# 894               2        Mr.
# 905               2        Mr.
# 1128              1        Mr.
# 973               1        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 914                       Flegenheim, Mrs. Alfred (Antoinette)  female   0.0
# 925          Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female   0.0
# 928                                        Roth, Miss. Sarah A  female   0.0
# 957          Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female   0.0
# 980                                    O'Donoghue, Ms. Bridget  female   0.0
# ...                                                        ...     ...   ...
# ...

# %%
df.sort_values(by=['Sex', 'Age'], ascending=(True, False))
# Out:
#              Pclass Salutation  \
# PassengerId
# 988               1        Mr.
# 1071              1        Mr.
# 1197              1        Mr.
# 1006              1        Mr.
# 940               1        Mr.
# ...             ...        ...
# 1272              3        Mr.
# 1276              2        Mr.
# 1305              3        Mr.
# 1308              3        Mr.
# 1309              3        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
# 1071         Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0
# 1197         Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0
# 1006                    Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0
# 940            Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0
# ...                                                        ...     ...   ...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 1309              3        Mr.                      Peter, Master. Michael J
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1305              3        Mr.                            Spector, Mr. Woolf
# ...             ...        ...                                           ...
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 895               3        Mr.                              Wirz, Mr. Albert
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 892               3        Mr.                              Kelly, Mr. James
#
# ...

# %% [markdown]
# ### .rank Method

# %%
df['Age'].rank() #Ranks values lowest to highest values
# Out:
# PassengerId
# 892     308.0
# 893     372.0
# 894     411.0
# 895     247.5
# 896     180.5
#         ...
# 1305     43.5
# 1306    333.5
# 1307    330.0
# 1308     43.5
# 1309     43.5
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].rank(ascending=False) #Highest Age will have lowest Rank
# Out:
# PassengerId
# 892     111.0
# 893      47.0
# 894       8.0
# 895     171.5
# 896     238.5
#         ...
# 1305    375.5
# 1306     85.5
# 1307     89.0
# 1308    375.5
# 1309    375.5
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# ### to_datetime() Method

# %%
df_dt=pd.DataFrame.from_dict({'Date':['20200101','20200102','20200103']})

df_dt
# Out:
#        Date
# 0  20200101
# 1  20200102
# 2  20200103

# %%
df_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
pd.to_datetime(df_dt['Date'])
# Out:
# 0   2020-01-01
# 1   2020-01-02
# 2   2020-01-03
# Name: Date, dtype: datetime64[ns]

# %%
df_dt["Date"]=pd.to_datetime(df_dt['Date'])

df_dt
# Out:
#         Date
# 0 2020-01-01
# 1 2020-01-02
# 2 2020-01-03

# %%
df_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 152.0 bytes

# %% [markdown]
# ### Filter DataFrame Based On Condition

# %%
df[df['Sex']=='male']
# Out:
#              Pclass Salutation                          Name   Sex   Age  \
# PassengerId
# 892               3        Mr.              Kelly, Mr. James  male  34.5
# 894               2        Mr.     Myles, Mr. Thomas Francis  male  62.0
# 895               3        Mr.              Wirz, Mr. Albert  male  27.0
# 897               3        Mr.    Svensson, Mr. Johan Cervin  male  14.0
# 899               2        Mr.  Caldwell, Mr. Albert Francis  male  26.0
# ...             ...        ...                           ...   ...   ...
# 1299              1        Mr.    Widener, Mr. George Dunton  male  50.0
# 1305              3        Mr.            Spector, Mr. Woolf  male   0.0
# 1307              3        Mr.  Saether, Mr. Simon Sivertsen  male  38.5
# 1308              3        Mr.           Ware, Mr. Frederick  male   0.0
# 1309              3        Mr.      Peter, Master. Michael J  male   0.0
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df[df['Sex']=='female']
# Out:
#              Pclass Salutation  \
# PassengerId
# 893               3        Mr.
# 896               3        Mr.
# 898               3        Mr.
# 900               3        Mr.
# 904               1        Mr.
# ...             ...        ...
# 1301              3        Mr.
# 1302              3        Mr.
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 893                         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 896             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 898                                     Connolly, Miss. Kate  female  30.0
# 900                Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 904            Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# ...                                                      ...     ...   ...
# ...

# %%
df[df['Age'] >= 25]
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 893               3        Mr.
# 894               2        Mr.
# 895               3        Mr.
# 898               3        Mr.
# ...             ...        ...
# 1299              1        Mr.
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
# 1307              3        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 892                                         Kelly, Mr. James    male  34.5
# 893                         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 894                                Myles, Mr. Thomas Francis    male  62.0
# 895                                         Wirz, Mr. Albert    male  27.0
# 898                                     Connolly, Miss. Kate  female  30.0
# ...                                                      ...     ...   ...
# ...

# %% [markdown]
# ### Filter Using More Than One Conditions

# %%
df[(df['Age'] >= 25) & (df['Age'] <= 50)]
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 893               3        Mr.
# 895               3        Mr.
# 898               3        Mr.
# 899               2        Mr.
# ...             ...        ...
# 1299              1        Mr.
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
# 1307              3        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 892                                         Kelly, Mr. James    male  34.5
# 893                         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 895                                         Wirz, Mr. Albert    male  27.0
# 898                                     Connolly, Miss. Kate  female  30.0
# 899                             Caldwell, Mr. Albert Francis    male  26.0
# ...                                                      ...     ...   ...
# ...

# %%
cond_1 = df['Age'] >= 25
cond_2 = df['Age'] <= 50

df[cond_1 & cond_2]
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 893               3        Mr.
# 895               3        Mr.
# 898               3        Mr.
# 899               2        Mr.
# ...             ...        ...
# 1299              1        Mr.
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
# 1307              3        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 892                                         Kelly, Mr. James    male  34.5
# 893                         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 895                                         Wirz, Mr. Albert    male  27.0
# 898                                     Connolly, Miss. Kate  female  30.0
# 899                             Caldwell, Mr. Albert Francis    male  26.0
# ...                                                      ...     ...   ...
# ...

# %%
df[(df['Age'] <= 10) | (df['Age'] >= 60)]
# Out:
#              Pclass Salutation                                  Name     Sex  \
# PassengerId
# 894               2        Mr.             Myles, Mr. Thomas Francis    male
# 902               3        Mr.                      Ilieff, Mr. Ylio    male
# 905               2        Mr.                  Howard, Mr. Benjamin    male
# 913               3        Mr.             Olsen, Master. Artur Karl    male
# 914               1        Mr.  Flegenheim, Mrs. Alfred (Antoinette)  female
# ...             ...        ...                                   ...     ...
# 1301              3        Mr.             Peacock, Miss. Treasteall  female
# 1302              3        Mr.                Naughton, Miss. Hannah  female
# 1305              3        Mr.                    Spector, Mr. Woolf    male
# 1308              3        Mr.                   Ware, Mr. Frederick    male
# 1309              3        Mr.              Peter, Master. Michael J    male
#
# ...

# %% [markdown]
# ### .isin() Method

# %%
df['Age'].isin([9,62])
# Out:
# PassengerId
# 892     False
# 893     False
# 894      True
# 895     False
# 896     False
#         ...
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# 1309    False
# Name: Age, Length: 418, dtype: bool

# %%
cond=df['Age'].isin([9,62])

df[cond]
# Out:
#              Pclass Salutation                        Name     Sex   Age  \
# PassengerId
# 894               2        Mr.   Myles, Mr. Thomas Francis    male  62.0
# 913               3        Mr.   Olsen, Master. Artur Karl    male   9.0
# 1175              3        Mr.  Touma, Miss. Maria Youssef  female   9.0
#
#              SibSp  Parch   Ticket     Fare Cabin Embarked     Ship
# PassengerId
# 894            0.0      0   240276   9.6875   NaN        Q  Titanic
# 913            0.0      1  C 17368   3.1708   NaN        S  Titanic
# 1175           1.0      1     2650  15.2458   NaN        C  Titanic

# %% [markdown]
# ### .isnull() and .notnull() Methods

# %%
df['Cabin'].isnull()
# Out:
# PassengerId
# 892      True
# 893      True
# 894      True
# 895      True
# 896      True
#         ...
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# 1309     True
# Name: Cabin, Length: 418, dtype: bool

# %%
df[df['Cabin'].isnull()]
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1304              3        Mr.                Henriksson, Miss. Jenny Lovisa
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
df[df['Cabin'].notnull()]
# Out:
#              Pclass Salutation  \
# PassengerId
# 904               1        Mr.
# 906               1        Mr.
# 916               1        Mr.
# 918               1        Mr.
# 920               1        Mr.
# ...             ...        ...
# 1296              1        Mr.
# 1297              2        Mr.
# 1299              1        Mr.
# 1303              1        Mr.
# 1306              1        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 904              Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 906          Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 916            Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 918                               Ostby, Miss. Helene Ragnhild  female  22.0
# 920                                    Brady, Mr. John Bertram    male  41.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### .between Method

# %%
df['Age'].between(25,50)
# Out:
# PassengerId
# 892      True
# 893      True
# 894     False
# 895      True
# 896     False
#         ...
# 1305    False
# 1306     True
# 1307     True
# 1308    False
# 1309    False
# Name: Age, Length: 418, dtype: bool

# %%
df[df['Age'].between(25,50)]
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 893               3        Mr.
# 895               3        Mr.
# 898               3        Mr.
# 899               2        Mr.
# ...             ...        ...
# 1299              1        Mr.
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
# 1307              3        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 892                                         Kelly, Mr. James    male  34.5
# 893                         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 895                                         Wirz, Mr. Albert    male  27.0
# 898                                     Connolly, Miss. Kate  female  30.0
# 899                             Caldwell, Mr. Albert Francis    male  26.0
# ...                                                      ...     ...   ...
# ...

# %%
df[df['Fare'].between(10,20)]
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 908               2        Mr.                             Keane, Mr. Daniel
# 917               3        Mr.                       Robins, Mr. Alexander A
# 932               3        Mr.                              Karun, Mr. Franz
# 935               2        Mr.         Corbett, Mrs. Walter H (Irene Colvin)
# ...             ...        ...                                           ...
# 1279              2        Mr.                               Ashby, Mr. John
# 1285              2        Mr.                          Gilbert, Mr. William
# 1297              2        Mr.  Nourney, Mr. Alfred (Baron von Drachstedt")"
# 1298              2        Mr.                     Ware, Mr. William Jeffery
# 1301              3        Mr.                     Peacock, Miss. Treasteall
#
# ...

# %% [markdown]
# ### Find Duplicates in DataFrame

# %%
df['Age'].duplicated()
# Out:
# PassengerId
# 892     False
# 893     False
# 894     False
# 895     False
# 896     False
#         ...
# 1305     True
# 1306     True
# 1307    False
# 1308     True
# 1309     True
# Name: Age, Length: 418, dtype: bool

# %%
#By default it will mark all except first occurance as duplicate

df[df['Age'].duplicated()]
# Out:
#              Pclass Salutation  \
# PassengerId
# 906               1        Mr.
# 909               3        Mr.
# 910               3        Mr.
# 914               1        Mr.
# 915               1        Mr.
# ...             ...        ...
# 1304              3        Mr.
# 1305              3        Mr.
# 1306              1        Mr.
# 1308              3        Mr.
# 1309              3        Mr.
#
#                                                           Name     Sex   Age  \
# PassengerId
# 906          Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 909                                          Assaf, Mr. Gerios    male  21.0
# 910                               Ilmakangas, Miss. Ida Livija  female  27.0
# 914                       Flegenheim, Mrs. Alfred (Antoinette)  female   0.0
# 915                            Williams, Mr. Richard Norris II    male  21.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df['Age'].duplicated(keep='last')]
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3        Mr.                    Svensson, Mr. Johan Cervin
# 898               3        Mr.                          Connolly, Miss. Kate
# ...             ...        ...                                           ...
# 1290              3        Mr.                Larsson-Rondberg, Mr. Edvard A
# 1300              3        Mr.               Riordan, Miss. Johanna Hannah""
# 1302              3        Mr.                        Naughton, Miss. Hannah
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1308              3        Mr.                           Ware, Mr. Frederick
#
# ...

# %%
#Show all the rows which are duplicate

df[df['Age'].duplicated(keep=False)]
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3        Mr.                    Svensson, Mr. Johan Cervin
# 898               3        Mr.                          Connolly, Miss. Kate
# ...             ...        ...                                           ...
# 1304              3        Mr.                Henriksson, Miss. Jenny Lovisa
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
#Show only unique values

~df['Age'].duplicated(keep=False)
# Out:
# PassengerId
# 892      True
# 893     False
# 894      True
# 895     False
# 896     False
#         ...
# 1305    False
# 1306    False
# 1307     True
# 1308    False
# 1309    False
# Name: Age, Length: 418, dtype: bool

# %%
df[~df['Age'].duplicated(keep=False)]
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 894               2        Mr.
# 919               3        Mr.
# 965               1        Mr.
# 973               1        Mr.
# 988               1        Mr.
# 1028              3        Mr.
# 1044              3        Mr.
# 1053              3        Mr.
# 1067              2        Mr.
# 1082              2        Mr.
# 1084              3        Mr.
# 1093              3        Mr.
# 1120              3        Mr.
# 1142              2        Mr.
# 1152              3        Mr.
# 1173              3        Mr.
# 1199              3        Mr.
# 1235              1        Mr.
# 1246              3        Mr.
# 1248              1        Mr.
# 1252              3        Mr.
# 1265              2        Mr.
# 1271              3        Mr.
# 1283              1        Mr.
# 1301              3        Mr.
# 1307              3        Mr.
#
# ...

# %% [markdown]
# ### drop_duplicates() Method

# %%
#To Check Duplicates in Rows i.e. All Columns of Rows

df.drop_duplicates()
# Out:
#              Pclass Salutation                                          Name  \
# PassengerId
# 892               3        Mr.                              Kelly, Mr. James
# 893               3        Mr.              Wilkes, Mrs. James (Ellen Needs)
# 894               2        Mr.                     Myles, Mr. Thomas Francis
# 895               3        Mr.                              Wirz, Mr. Albert
# 896               3        Mr.  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...             ...        ...                                           ...
# 1305              3        Mr.                            Spector, Mr. Woolf
# 1306              1        Mr.                  Oliva y Ocana, Dona. Fermina
# 1307              3        Mr.                  Saether, Mr. Simon Sivertsen
# 1308              3        Mr.                           Ware, Mr. Frederick
# 1309              3        Mr.                      Peter, Master. Michael J
#
# ...

# %%
#drop duplicates in a column

df.drop_duplicates(subset=['Age'])
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 893               3        Mr.
# 894               2        Mr.
# 895               3        Mr.
# 896               3        Mr.
# ...             ...        ...
# 1265              2        Mr.
# 1271              3        Mr.
# 1283              1        Mr.
# 1301              3        Mr.
# 1307              3        Mr.
#
#                                                        Name     Sex   Age  \
# PassengerId
# 892                                        Kelly, Mr. James    male  34.5
# 893                        Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 894                               Myles, Mr. Thomas Francis    male  62.0
# 895                                        Wirz, Mr. Albert    male  27.0
# 896            Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ...                                                     ...     ...   ...
# ...

# %%
df.drop_duplicates(subset=['Age'], keep='last')
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 894               2        Mr.
# 919               3        Mr.
# 965               1        Mr.
# 973               1        Mr.
# ...             ...        ...
# 1303              1        Mr.
# 1304              3        Mr.
# 1306              1        Mr.
# 1307              3        Mr.
# 1309              3        Mr.
#
#                                                         Name     Sex   Age  \
# PassengerId
# 892                                         Kelly, Mr. James    male  34.5
# 894                                Myles, Mr. Thomas Francis    male  62.0
# 919                                        Daher, Mr. Shedid    male  22.5
# 965                          Ovies y Rodriguez, Mr. Servando    male  28.5
# 973                                       Straus, Mr. Isidor    male  67.0
# ...                                                      ...     ...   ...
# ...

# %%
df.drop_duplicates(subset=['Age'], keep=False)
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 894               2        Mr.
# 919               3        Mr.
# 965               1        Mr.
# 973               1        Mr.
# 988               1        Mr.
# 1028              3        Mr.
# 1044              3        Mr.
# 1053              3        Mr.
# 1067              2        Mr.
# 1082              2        Mr.
# 1084              3        Mr.
# 1093              3        Mr.
# 1120              3        Mr.
# 1142              2        Mr.
# 1152              3        Mr.
# 1173              3        Mr.
# 1199              3        Mr.
# 1235              1        Mr.
# 1246              3        Mr.
# 1248              1        Mr.
# 1252              3        Mr.
# 1265              2        Mr.
# 1271              3        Mr.
# 1283              1        Mr.
# 1301              3        Mr.
# 1307              3        Mr.
#
# ...

# %%
#Check duplicates on Multiple columns

df.drop_duplicates(subset=['Age', 'Sex'], keep=False)
# Out:
#              Pclass Salutation  \
# PassengerId
# 892               3        Mr.
# 894               2        Mr.
# 905               2        Mr.
# 913               3        Mr.
# 919               3        Mr.
# 947               3        Mr.
# 965               1        Mr.
# 973               1        Mr.
# 981               2        Mr.
# 988               1        Mr.
# 992               1        Mr.
# 1005              3        Mr.
# 1006              1        Mr.
# 1028              3        Mr.
# 1032              3        Mr.
# 1044              3        Mr.
# 1053              3        Mr.
# 1058              1        Mr.
# 1067              2        Mr.
# 1069              1        Mr.
# 1073              1        Mr.
# 1082              2        Mr.
# 1084              3        Mr.
# 1086              2        Mr.
# 1093              3        Mr.
# 1095              2        Mr.
# 1110              1        Mr.
# 1116              1        Mr.
# ...

# %% [markdown]
# ### Identify and Count Unique Values using nunique and unique Methods

# %%
#Doesn't includes NULL by default

df['Cabin'].nunique()
# Out:
# 76

# %%
df['Cabin'].nunique(dropna=False)
# Out:
# 77

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
len(df['Cabin'].unique())
# Out:
# 77

# %% [markdown]
# ### set_index and reset_inndex methods

# %%
df_n = pd.read_csv('test.csv')

df_n
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_n.set_index("PassengerId", inplace=True)

df_n
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df_n.reset_index()
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_n.reset_index(drop=True)
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_n.reset_index(drop=False, inplace=True)

df_n
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_n.set_index('PassengerId', inplace=True)

df_n
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df_n.reset_index(inplace=True)
df_n.set_index('Ticket', inplace=True)

df_n
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       3
# 363272                      893       3
# 240276                      894       2
# 315154                      895       3
# 3101298                     896       3
# ...                         ...     ...
# A.5. 3236                  1305       3
# PC 17758                   1306       1
# SOTON/O.Q. 3101262         1307       3
# 359309                     1308       3
# 2668                       1309       3
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis    male
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %% [markdown]
# ### Retrieve Rows by Index Label with .loc[] Accessor

# %%
df_n.loc['A.5. 3236']
# Out:
# PassengerId                  1305
# Pclass                          3
# Name           Spector, Mr. Woolf
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Fare                         8.05
# Cabin                         NaN
# Embarked                        S
# Name: A.5. 3236, dtype: object

# %%
df_n.loc['A.5. 3236':'SOTON/O.Q. 3101262']
# Out:
#                     PassengerId  Pclass                          Name     Sex  \
# Ticket
# A.5. 3236                  1305       3            Spector, Mr. Woolf    male
# PC 17758                   1306       1  Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262         1307       3  Saether, Mr. Simon Sivertsen    male
#
#                      Age  SibSp  Parch    Fare Cabin Embarked
# Ticket
# A.5. 3236            NaN      0      0    8.05   NaN        S
# PC 17758            39.0      0      0  108.90  C105        C
# SOTON/O.Q. 3101262  38.5      0      0    7.25   NaN        S

# %%
df_n.loc['A.5. 3236':'SOTON/O.Q. 3101262':2]
# Out:
#                     PassengerId  Pclass                          Name   Sex  \
# Ticket
# A.5. 3236                  1305       3            Spector, Mr. Woolf  male
# SOTON/O.Q. 3101262         1307       3  Saether, Mr. Simon Sivertsen  male
#
#                      Age  SibSp  Parch  Fare Cabin Embarked
# Ticket
# A.5. 3236            NaN      0      0  8.05   NaN        S
# SOTON/O.Q. 3101262  38.5      0      0  7.25   NaN        S

# %%
df_n.loc['A.5. 3236':]
# Out:
#                     PassengerId  Pclass                          Name     Sex  \
# Ticket
# A.5. 3236                  1305       3            Spector, Mr. Woolf    male
# PC 17758                   1306       1  Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262         1307       3  Saether, Mr. Simon Sivertsen    male
# 359309                     1308       3           Ware, Mr. Frederick    male
# 2668                       1309       3      Peter, Master. Michael J    male
#
#                      Age  SibSp  Parch      Fare Cabin Embarked
# Ticket
# A.5. 3236            NaN      0      0    8.0500   NaN        S
# PC 17758            39.0      0      0  108.9000  C105        C
# SOTON/O.Q. 3101262  38.5      0      0    7.2500   NaN        S
# 359309               NaN      0      0    8.0500   NaN        S
# 2668                 NaN      1      1   22.3583   NaN        C

# %%
df_n.loc[['A.5. 3236','SOTON/O.Q. 3101262']]
# Out:
#                     PassengerId  Pclass                          Name   Sex  \
# Ticket
# A.5. 3236                  1305       3            Spector, Mr. Woolf  male
# SOTON/O.Q. 3101262         1307       3  Saether, Mr. Simon Sivertsen  male
#
#                      Age  SibSp  Parch  Fare Cabin Embarked
# Ticket
# A.5. 3236            NaN      0      0  8.05   NaN        S
# SOTON/O.Q. 3101262  38.5      0      0  7.25   NaN        S

# %%
'SOTON/O.Q. 3101262' in df_n.index
# Out:
# True

# %% [markdown]
# ### Retrieve Rows by Index Position with .iloc[] Accessor

# %%
df_n.iloc[5]
# Out:
# PassengerId                           897
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                    14
# SibSp                                   0
# Parch                                   0
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 7538, dtype: object

# %%
df_n.iloc[:,2:4]
# Out:
#                                                             Name     Sex
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis    male
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# A.5. 3236                                     Spector, Mr. Woolf    male
# PC 17758                            Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262                  Saether, Mr. Simon Sivertsen    male
# 359309                                       Ware, Mr. Frederick    male
# 2668                                    Peter, Master. Michael J    male
#
# [418 rows x 2 columns]

# %%
df_n.iloc[0:5,:]
# Out:
#          PassengerId  Pclass                                          Name  \
# Ticket
# 330911           892       3                              Kelly, Mr. James
# 363272           893       3              Wilkes, Mrs. James (Ellen Needs)
# 240276           894       2                     Myles, Mr. Thomas Francis
# 315154           895       3                              Wirz, Mr. Albert
# 3101298          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#             Sex   Age  SibSp  Parch     Fare Cabin Embarked
# Ticket
# 330911     male  34.5      0      0   7.8292   NaN        Q
# 363272   female  47.0      1      0   7.0000   NaN        S
# 240276     male  62.0      0      0   9.6875   NaN        Q
# 315154     male  27.0      0      0   8.6625   NaN        S
# 3101298  female  22.0      1      1  12.2875   NaN        S

# %%
df_n.iloc[0:5]
# Out:
#          PassengerId  Pclass                                          Name  \
# Ticket
# 330911           892       3                              Kelly, Mr. James
# 363272           893       3              Wilkes, Mrs. James (Ellen Needs)
# 240276           894       2                     Myles, Mr. Thomas Francis
# 315154           895       3                              Wirz, Mr. Albert
# 3101298          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#             Sex   Age  SibSp  Parch     Fare Cabin Embarked
# Ticket
# 330911     male  34.5      0      0   7.8292   NaN        Q
# 363272   female  47.0      1      0   7.0000   NaN        S
# 240276     male  62.0      0      0   9.6875   NaN        Q
# 315154     male  27.0      0      0   8.6625   NaN        S
# 3101298  female  22.0      1      1  12.2875   NaN        S

# %%
df_n.iloc[:,:]
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       3
# 363272                      893       3
# 240276                      894       2
# 315154                      895       3
# 3101298                     896       3
# ...                         ...     ...
# A.5. 3236                  1305       3
# PC 17758                   1306       1
# SOTON/O.Q. 3101262         1307       3
# 359309                     1308       3
# 2668                       1309       3
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis    male
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.iloc[[1,3,7]]
# Out:
#         PassengerId  Pclass                              Name     Sex   Age  \
# Ticket
# 363272          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 315154          895       3                  Wirz, Mr. Albert    male  27.0
# 248738          899       2      Caldwell, Mr. Albert Francis    male  26.0
#
#         SibSp  Parch     Fare Cabin Embarked
# Ticket
# 363272      1      0   7.0000   NaN        S
# 315154      0      0   8.6625   NaN        S
# 248738      1      1  29.0000   NaN        S

# %% [markdown]
# ### Second Argument to loc and iloc Accessors

# %%
df_n.loc['SOTON/O.Q. 3101262','Name']
# Out:
# 'Saether, Mr. Simon Sivertsen'

# %%
df_n.loc['SOTON/O.Q. 3101262',['Name','Sex','Age']]
# Out:
# Name    Saether, Mr. Simon Sivertsen
# Sex                             male
# Age                             38.5
# Name: SOTON/O.Q. 3101262, dtype: object

# %%
df_n.loc[['SOTON/O.Q. 3101262','A.5. 3236'],['Name','Sex','Age']]
# Out:
#                                             Name   Sex   Age
# Ticket
# SOTON/O.Q. 3101262  Saether, Mr. Simon Sivertsen  male  38.5
# A.5. 3236                     Spector, Mr. Woolf  male   NaN

# %%
df_n.loc['A.5. 3236':'SOTON/O.Q. 3101262','Name':'Age']
# Out:
#                                             Name     Sex   Age
# Ticket
# A.5. 3236                     Spector, Mr. Woolf    male   NaN
# PC 17758            Oliva y Ocana, Dona. Fermina  female  39.0
# SOTON/O.Q. 3101262  Saether, Mr. Simon Sivertsen    male  38.5

# %%
df_n.iloc[10,2]
# Out:
# 'Ilieff, Mr. Ylio'

# %%
df_n.iloc[10,2:5]
# Out:
# Name    Ilieff, Mr. Ylio
# Sex                 male
# Age                  NaN
# Name: 349220, dtype: object

# %%
df_n.iloc[10:15,2:5]
# Out:
#                                                           Name     Sex   Age
# Ticket
# 349220                                        Ilieff, Mr. Ylio    male   NaN
# 694                                 Jones, Mr. Charles Cresson    male  46.0
# 21228            Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 24065                                     Howard, Mr. Benjamin    male  63.0
# W.E.P. 5734  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0

# %% [markdown]
# ### Set New Value for a Specific Cell

# %%
df_n.loc['W.E.P. 5734','Name']
# Out:
# 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)'

# %%
df_n.loc['W.E.P. 5734','Name'] = 'Mr. Fuller'

df_n.loc['W.E.P. 5734','Name']
# Out:
# 'Mr. Fuller'

# %%
df_n.loc['24065',['Name','Sex','Age']] = ['Ms. Howard','female',50]

df_n.loc['24065']
# Out:
#         PassengerId  Pclass        Name     Sex   Age  SibSp  Parch  Fare  \
# Ticket
# 24065           905       2  Ms. Howard  female  50.0      1      0  26.0
# 24065          1105       2  Ms. Howard  female  50.0      1      0  26.0
#
#        Cabin Embarked
# Ticket
# 24065    NaN        S
# 24065    NaN        S

# %% [markdown]
# ### Set Multiple Values in DataFrame

# %%
df_n.loc[df_n['Pclass']==3, 'Pclass'] = 5

df_n
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       2
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5. 3236                  1305       5
# PC 17758                   1306       1
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis    male
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
pclass_is_1 = df_n['Pclass']==1

df_n.loc[pclass_is_1, 'Pclass'] = 4

df_n
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       2
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5. 3236                  1305       5
# PC 17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis    male
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.loc[df_n['Pclass']==2, ['Pclass','Sex']] = [6,'female']

df_n
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5. 3236                  1305       5
# PC 17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.loc[df_n['Age']==34.5, 'Age'] = 50

df_n
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5. 3236                  1305       5
# PC 17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %% [markdown]
# ### Rename Index Label or Column Names in a Dataframe

# %%
df_n.rename(mapper={"A.5. 3236":"A.5._3236",
                    "PC 17758":"PC_17758"})
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5._3236                  1305       5
# PC_17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(mapper={"A.5. 3236":"A.5._3236",
                    "PC 17758":"PC_17758"}, axis=0)
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5._3236                  1305       5
# PC_17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(mapper={"A.5. 3236":"A.5._3236",
                    "PC 17758":"PC_17758"}, axis='rows')
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5._3236                  1305       5
# PC_17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(mapper={"A.5. 3236":"A.5._3236",
                    "PC 17758":"PC_17758"}, axis='index')
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5._3236                  1305       5
# PC_17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(index={"A.5. 3236":"A.5._3236",
                    "PC 17758":"PC_17758"})
# Out:
#                     PassengerId  Pclass  \
# Ticket
# 330911                      892       5
# 363272                      893       5
# 240276                      894       6
# 315154                      895       5
# 3101298                     896       5
# ...                         ...     ...
# A.5._3236                  1305       5
# PC_17758                   1306       4
# SOTON/O.Q. 3101262         1307       5
# 359309                     1308       5
# 2668                       1309       5
#
#                                                             Name     Sex  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(mapper={"PassengerId":"Passenger_Id",
                    "Sex":"Gender"}, axis=1)
# Out:
#                     Passenger_Id  Pclass  \
# Ticket
# 330911                       892       5
# 363272                       893       5
# 240276                       894       6
# 315154                       895       5
# 3101298                      896       5
# ...                          ...     ...
# A.5. 3236                   1305       5
# PC 17758                    1306       4
# SOTON/O.Q. 3101262          1307       5
# 359309                      1308       5
# 2668                        1309       5
#
#                                                             Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(mapper={"PassengerId":"Passenger_Id",
                    "Sex":"Gender"}, axis='columns')
# Out:
#                     Passenger_Id  Pclass  \
# Ticket
# 330911                       892       5
# 363272                       893       5
# 240276                       894       6
# 315154                       895       5
# 3101298                      896       5
# ...                          ...     ...
# A.5. 3236                   1305       5
# PC 17758                    1306       4
# SOTON/O.Q. 3101262          1307       5
# 359309                      1308       5
# 2668                        1309       5
#
#                                                             Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.rename(columns={"PassengerId":"Passenger_Id",
                    "Sex":"Gender"})
# Out:
#                     Passenger_Id  Pclass  \
# Ticket
# 330911                       892       5
# 363272                       893       5
# 240276                       894       6
# 315154                       895       5
# 3101298                      896       5
# ...                          ...     ...
# A.5. 3236                   1305       5
# PC 17758                    1306       4
# SOTON/O.Q. 3101262          1307       5
# 359309                      1308       5
# 2668                        1309       5
#
#                                                             Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
df_n.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_n.columns=['Passenger_Id', 'Pclass', 'Passenger Name', 'Gender', 'Age', 'SibSp', 'Parch', 'Fare',
       'Cabin', 'Embarked']

# %%
df_n
# Out:
#                     Passenger_Id  Pclass  \
# Ticket
# 330911                       892       5
# 363272                       893       5
# 240276                       894       6
# 315154                       895       5
# 3101298                      896       5
# ...                          ...     ...
# A.5. 3236                   1305       5
# PC 17758                    1306       4
# SOTON/O.Q. 3101262          1307       5
# 359309                      1308       5
# 2668                        1309       5
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %% [markdown]
# ### Delete Rows or Columns From a DataFrame  (drop(), pop(), del)

# %%
df_n.drop('SOTON/O.Q. 3101262')
# Out:
#            Passenger_Id  Pclass                                Passenger Name  \
# Ticket
# 330911              892       5                              Kelly, Mr. James
# 363272              893       5              Wilkes, Mrs. James (Ellen Needs)
# 240276              894       6                     Myles, Mr. Thomas Francis
# 315154              895       5                              Wirz, Mr. Albert
# 3101298             896       5  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...                 ...     ...                                           ...
# 347086             1304       5                Henriksson, Miss. Jenny Lovisa
# A.5. 3236          1305       5                            Spector, Mr. Woolf
# PC 17758           1306       4                  Oliva y Ocana, Dona. Fermina
# 359309             1308       5                           Ware, Mr. Frederick
# 2668               1309       5                      Peter, Master. Michael J
#
# ...

# %%
df_n.drop(['SOTON/O.Q. 3101262','330911'])
# Out:
#            Passenger_Id  Pclass                                Passenger Name  \
# Ticket
# 363272              893       5              Wilkes, Mrs. James (Ellen Needs)
# 240276              894       6                     Myles, Mr. Thomas Francis
# 315154              895       5                              Wirz, Mr. Albert
# 3101298             896       5  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 7538                897       5                    Svensson, Mr. Johan Cervin
# ...                 ...     ...                                           ...
# 347086             1304       5                Henriksson, Miss. Jenny Lovisa
# A.5. 3236          1305       5                            Spector, Mr. Woolf
# PC 17758           1306       4                  Oliva y Ocana, Dona. Fermina
# 359309             1308       5                           Ware, Mr. Frederick
# 2668               1309       5                      Peter, Master. Michael J
#
# ...

# %%
df_n.drop('Pclass', axis=1)
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %%
df_n.drop(['Pclass','SibSp'], axis=1)
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %%
df_n
# Out:
#                     Passenger_Id  Pclass  \
# Ticket
# 330911                       892       5
# 363272                       893       5
# 240276                       894       6
# 315154                       895       5
# 3101298                      896       5
# ...                          ...     ...
# A.5. 3236                   1305       5
# PC 17758                    1306       4
# SOTON/O.Q. 3101262          1307       5
# 359309                      1308       5
# 2668                        1309       5
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...

# %%
#Pop removes as well as return the Series value which can be then used to save in another variable

df_n.pop('Pclass')
# Out:
# Ticket
# 330911                5
# 363272                5
# 240276                6
# 315154                5
# 3101298               5
#                      ..
# A.5. 3236             5
# PC 17758              4
# SOTON/O.Q. 3101262    5
# 359309                5
# 2668                  5
# Name: Pclass, Length: 418, dtype: int64

# %%
df_n
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %%
del df_n['SibSp']

# %%
df_n
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %% [markdown]
# ### Select Random Sample of DataFrame

# %%
#To select random rows from dataframe

df_n.sample()
# Out:
#         Passenger_Id      Passenger Name  Gender  Age  Parch  Fare Cabin  \
# Ticket
# 36568           1092  Murphy, Miss. Nora  female  NaN      0  15.5   NaN
#
#        Embarked
# Ticket
# 36568         Q

# %%
#To select random 5 rows from dataframe

df_n.sample(5)
# Out:
#         Passenger_Id              Passenger Name  Gender   Age  Parch  \
# Ticket
# 345501          1151    Midtsjo, Mr. Karl Albert    male  21.0      0
# 237670          1238  Botsford, Mr. William Hull  female  26.0      0
# 7266            1145    Salander, Mr. Karl Johan    male  24.0      0
# 16966           1263   Wilson, Miss. Helen Alice  female  31.0      0
# 349202          1187        Angheloff, Mr. Minko    male  26.0      0
#
#             Fare    Cabin Embarked
# Ticket
# 345501    7.7750      NaN        S
# 237670   13.0000      NaN        S
# 7266      9.3250      NaN        S
# 16966   134.5000  E39 E41        C
# 349202    7.8958      NaN        S

# %%
df_n.sample(frac = .03)
# Out:
#             Passenger_Id                 Passenger Name  Gender   Age  Parch  \
# Ticket
# CA 31352            1170           Ware, Mr. John James  female  30.0      0
# 347090               954   Bjorklund, Mr. Ernst Herbert    male  18.0      0
# 345775              1146            Wenzel, Mr. Linhart    male  32.5      0
# 368702               971         Doyle, Miss. Elizabeth  female  24.0      0
# 7266                1145       Salander, Mr. Karl Johan    male  24.0      0
# 349235              1157          Lyntakoff, Mr. Stanko    male   NaN      0
# 2926                1169          Faunthorpe, Mr. Harry  female  40.0      0
# PC 17613            1100  Rosenbaum, Miss. Edith Louise  female  33.0      0
# 28664               1293                Gale, Mr. Harry  female  38.0      0
# 345501              1151       Midtsjo, Mr. Karl Albert    male  21.0      0
# 350410              1153  Nilsson, Mr. August Ferdinand    male  21.0      0
# ...

# %%
#To select random 3 columns from dataframe

df_n.sample(3, axis=1)
# Out:
#                      Age      Fare  \
# Ticket
# 330911              50.0    7.8292
# 363272              47.0    7.0000
# 240276              62.0    9.6875
# 315154              27.0    8.6625
# 3101298             22.0   12.2875
# ...                  ...       ...
# A.5. 3236            NaN    8.0500
# PC 17758            39.0  108.9000
# SOTON/O.Q. 3101262  38.5    7.2500
# 359309               NaN    8.0500
# 2668                 NaN   22.3583
#
#                                                   Passenger Name
# Ticket
# 330911                                          Kelly, Mr. James
# 363272                          Wilkes, Mrs. James (Ellen Needs)
# 240276                                 Myles, Mr. Thomas Francis
# 315154                                          Wirz, Mr. Albert
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...                                                          ...
# ...

# %%
df_n.sample(5, axis='columns')
# Out:
#                                                   Passenger Name      Fare  \
# Ticket
# 330911                                          Kelly, Mr. James    7.8292
# 363272                          Wilkes, Mrs. James (Ellen Needs)    7.0000
# 240276                                 Myles, Mr. Thomas Francis    9.6875
# 315154                                          Wirz, Mr. Albert    8.6625
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)   12.2875
# ...                                                          ...       ...
# A.5. 3236                                     Spector, Mr. Woolf    8.0500
# PC 17758                            Oliva y Ocana, Dona. Fermina  108.9000
# SOTON/O.Q. 3101262                  Saether, Mr. Simon Sivertsen    7.2500
# 359309                                       Ware, Mr. Frederick    8.0500
# 2668                                    Peter, Master. Michael J   22.3583
#
#                    Cabin  Passenger_Id   Age
# Ticket
# ...

# %% [markdown]
# ### .nsmallest() and .nlargest() Methods

# %%
df_n.nsmallest(1,'Fare')
# Out:
#         Passenger_Id                         Passenger Name Gender  Age  \
# Ticket
# 112051          1158  Chisholm, Mr. Roderick Robert Crispin   male  NaN
#
#         Parch  Fare Cabin Embarked
# Ticket
# 112051      0   0.0   NaN        S

# %%
df_n.nsmallest(3,'Fare')
# Out:
#          Passenger_Id                         Passenger Name Gender   Age  \
# Ticket
# 112051           1158  Chisholm, Mr. Roderick Robert Crispin   male   NaN
# 112058           1264                Ismay, Mr. Joseph Bruce   male  49.0
# C 17368           913              Olsen, Master. Artur Karl   male   9.0
#
#          Parch    Fare        Cabin Embarked
# Ticket
# 112051       0  0.0000          NaN        S
# 112058       0  0.0000  B52 B54 B56        S
# C 17368      1  3.1708          NaN        S

# %%
df_n.nlargest(1,'Fare')
# Out:
#           Passenger_Id                                     Passenger Name  \
# Ticket
# PC 17755          1235  Cardeza, Mrs. James Warburton Martinez (Charlo...
#
#           Gender   Age  Parch      Fare        Cabin Embarked
# Ticket
# PC 17755  female  58.0      1  512.3292  B51 B53 B55        C

# %%
df_n.nlargest(3,'Fare')
# Out:
#           Passenger_Id                                     Passenger Name  \
# Ticket
# PC 17755          1235  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 19950              945                         Fortune, Miss. Ethel Flora
# 19950              961                Fortune, Mrs. Mark (Mary McDougald)
#
#           Gender   Age  Parch      Fare        Cabin Embarked
# Ticket
# PC 17755  female  58.0      1  512.3292  B51 B53 B55        C
# 19950     female  28.0      2  263.0000  C23 C25 C27        S
# 19950     female  60.0      4  263.0000  C23 C25 C27        S

# %%
df_n.nlargest(3,['Passenger_Id','Fare'])
# Out:
#                     Passenger_Id                Passenger Name Gender   Age  \
# Ticket
# 2668                        1309      Peter, Master. Michael J   male   NaN
# 359309                      1308           Ware, Mr. Frederick   male   NaN
# SOTON/O.Q. 3101262          1307  Saether, Mr. Simon Sivertsen   male  38.5
#
#                     Parch     Fare Cabin Embarked
# Ticket
# 2668                    1  22.3583   NaN        C
# 359309                  0   8.0500   NaN        S
# SOTON/O.Q. 3101262      0   7.2500   NaN        S

# %%
#To find largest or smallest from a Series

df_n['Fare'].nlargest(3)
# Out:
# Ticket
# PC 17755    512.3292
# 19950       263.0000
# 19950       263.0000
# Name: Fare, dtype: float64

# %%
df_n['Fare'].nsmallest(3)
# Out:
# Ticket
# 112051     0.0000
# 112058     0.0000
# C 17368    3.1708
# Name: Fare, dtype: float64

# %% [markdown]
# ### Filter DataFrame with .where() and .query() Methods

# %%
#where fills null in non-matching rows

df_n.where(df_n['Gender']=='male')
# Out:
#                     Passenger_Id                Passenger Name Gender   Age  \
# Ticket
# 330911                     892.0              Kelly, Mr. James   male  50.0
# 363272                       NaN                           NaN    NaN   NaN
# 240276                       NaN                           NaN    NaN   NaN
# 315154                     895.0              Wirz, Mr. Albert   male  27.0
# 3101298                      NaN                           NaN    NaN   NaN
# ...                          ...                           ...    ...   ...
# A.5. 3236                 1305.0            Spector, Mr. Woolf   male   NaN
# PC 17758                     NaN                           NaN    NaN   NaN
# SOTON/O.Q. 3101262        1307.0  Saether, Mr. Simon Sivertsen   male  38.5
# 359309                    1308.0           Ware, Mr. Frederick   male   NaN
# 2668                      1309.0      Peter, Master. Michael J   male   NaN
#
# ...

# %%
df_n.where(df_n['Age'] >= 30)
# Out:
#                     Passenger_Id                    Passenger Name  Gender  \
# Ticket
# 330911                     892.0                  Kelly, Mr. James    male
# 363272                     893.0  Wilkes, Mrs. James (Ellen Needs)  female
# 240276                     894.0         Myles, Mr. Thomas Francis  female
# 315154                       NaN                               NaN     NaN
# 3101298                      NaN                               NaN     NaN
# ...                          ...                               ...     ...
# A.5. 3236                    NaN                               NaN     NaN
# PC 17758                  1306.0      Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262        1307.0      Saether, Mr. Simon Sivertsen    male
# 359309                       NaN                               NaN     NaN
# 2668                         NaN                               NaN     NaN
#
#                      Age  Parch      Fare Cabin Embarked
# ...

# %%
df_n.where((df_n['Gender']=='male') & (df_n['Age'] >= 30))
# Out:
#                     Passenger_Id                Passenger Name Gender   Age  \
# Ticket
# 330911                     892.0              Kelly, Mr. James   male  50.0
# 363272                       NaN                           NaN    NaN   NaN
# 240276                       NaN                           NaN    NaN   NaN
# 315154                       NaN                           NaN    NaN   NaN
# 3101298                      NaN                           NaN    NaN   NaN
# ...                          ...                           ...    ...   ...
# A.5. 3236                    NaN                           NaN    NaN   NaN
# PC 17758                     NaN                           NaN    NaN   NaN
# SOTON/O.Q. 3101262        1307.0  Saether, Mr. Simon Sivertsen   male  38.5
# 359309                       NaN                           NaN    NaN   NaN
# 2668                         NaN                           NaN    NaN   NaN
#
# ...

# %%
df_n.where((df_n['Gender']=='male') | (df_n['Age'] >= 30))
# Out:
#                     Passenger_Id                    Passenger Name  Gender  \
# Ticket
# 330911                     892.0                  Kelly, Mr. James    male
# 363272                     893.0  Wilkes, Mrs. James (Ellen Needs)  female
# 240276                     894.0         Myles, Mr. Thomas Francis  female
# 315154                     895.0                  Wirz, Mr. Albert    male
# 3101298                      NaN                               NaN     NaN
# ...                          ...                               ...     ...
# A.5. 3236                 1305.0                Spector, Mr. Woolf    male
# PC 17758                  1306.0      Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262        1307.0      Saether, Mr. Simon Sivertsen    male
# 359309                    1308.0               Ware, Mr. Frederick    male
# 2668                      1309.0          Peter, Master. Michael J    male
#
#                      Age  Parch      Fare Cabin Embarked
# ...

# %% [markdown]
# #### .query() Method

# %%
#query method doesn't work in case column name contains spaces

df_n.query('Age >= 30')
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 330972                       898
# 694                          903
# ...                          ...
# 17765                       1296
# 113503                      1299
# 19928                       1303
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
#
#                                                      Passenger Name  Gender  \
# Ticket
# 330911                                             Kelly, Mr. James    male
# 363272                             Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                    Myles, Mr. Thomas Francis  female
# 330972                                         Connolly, Miss. Kate  female
# 694                                      Jones, Mr. Charles Cresson    male
# ...                                                             ...     ...
# ...

# %%
df_n.query('Age >= 30 & Gender=="male"') # both &, and works
# Out:
#                     Passenger_Id                Passenger Name Gender   Age  \
# Ticket
# 330911                       892              Kelly, Mr. James   male  50.0
# 694                          903    Jones, Mr. Charles Cresson   male  46.0
# PC 17603                     912        Rothschild, Mr. Martin   male  55.0
# A/5. 3337                    917       Robins, Mr. Alexander A   male  50.0
# 113054                       920       Brady, Mr. John Bertram   male  41.0
# ...                          ...                           ...    ...   ...
# 680                         1270   Hipkins, Mr. William Edward   male  55.0
# 21332                       1291      Conlon, Mr. Thomas Henry   male  31.0
# 17765                       1296  Frauenthal, Mr. Isaac Gerald   male  43.0
# 113503                      1299    Widener, Mr. George Dunton   male  50.0
# SOTON/O.Q. 3101262          1307  Saether, Mr. Simon Sivertsen   male  38.5
#
# ...

# %%
df_n.query('Age >= 30 or Gender=="male"') # both or,| works
# Out:
#                     Passenger_Id                    Passenger Name  Gender  \
# Ticket
# 330911                       892                  Kelly, Mr. James    male
# 363272                       893  Wilkes, Mrs. James (Ellen Needs)  female
# 240276                       894         Myles, Mr. Thomas Francis  female
# 315154                       895                  Wirz, Mr. Albert    male
# 7538                         897        Svensson, Mr. Johan Cervin    male
# ...                          ...                               ...     ...
# A.5. 3236                   1305                Spector, Mr. Woolf    male
# PC 17758                    1306      Oliva y Ocana, Dona. Fermina  female
# SOTON/O.Q. 3101262          1307      Saether, Mr. Simon Sivertsen    male
# 359309                      1308               Ware, Mr. Frederick    male
# 2668                        1309          Peter, Master. Michael J    male
#
#                      Age  Parch      Fare Cabin Embarked
# ...

# %% [markdown]
# ### .apply method on DataFrame

# %%
#Column wise

df_n['Age'] = df_n['Age'].apply(lambda x: x*2 if x > 50 else x)

df_n
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %%
#Row Wise

#Helps in matching conditions based on multiple columns of a row

def age_check(row):
    age=row[3]
    fare=row[5]
    
    if age > 50 and fare < 20:
        return 'Yes'
    else:
        return 'No'

df_n.apply(age_check, axis=1)
# Out:
# Ticket
# 330911                 No
# 363272                 No
# 240276                Yes
# 315154                 No
# 3101298                No
#                      ...
# A.5. 3236              No
# PC 17758               No
# SOTON/O.Q. 3101262     No
# 359309                 No
# 2668                   No
# Length: 418, dtype: object

# %% [markdown]
# ### Creating a copy of a dataframe with .copy() method

# %%
#It helps avoiding overriding original values of a dataframe

df_new = df_n.copy()

# %%
df_new
# Out:
#                     Passenger_Id  \
# Ticket
# 330911                       892
# 363272                       893
# 240276                       894
# 315154                       895
# 3101298                      896
# ...                          ...
# A.5. 3236                   1305
# PC 17758                    1306
# SOTON/O.Q. 3101262          1307
# 359309                      1308
# 2668                        1309
#
#                                                   Passenger Name  Gender  \
# Ticket
# 330911                                          Kelly, Mr. James    male
# 363272                          Wilkes, Mrs. James (Ellen Needs)  female
# 240276                                 Myles, Mr. Thomas Francis  female
# 315154                                          Wirz, Mr. Albert    male
# 3101298             Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                          ...     ...
# ...

# %%
name = df['Name'].copy

name
# Out:
# <bound method NDFrame.copy of PassengerId
# 892                                 Kelly, Mr. James
# 893                 Wilkes, Mrs. James (Ellen Needs)
# 894                        Myles, Mr. Thomas Francis
# 895                                 Wirz, Mr. Albert
# 896     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                             ...
# 1305                              Spector, Mr. Woolf
# 1306                    Oliva y Ocana, Dona. Fermina
# 1307                    Saether, Mr. Simon Sivertsen
# 1308                             Ware, Mr. Frederick
# 1309                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object>
